# %%
import numpy as np
# %matplotlib ipympl
import matplotlib.pyplot as plt

from trusslib_v1_1 import *
from cross_truss import *

# %%
truss_extrude = setup_truss('extruded_3d_truss.txt')
truss_extrude.draw()
truss_extrude.solve()
truss_extrude.plot(magnification=10, structure=False)
truss_extrude.print_displacements(17)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 17: [-0.0014285714285714067, 0.009469181606780137, 0.01726760178178538]
