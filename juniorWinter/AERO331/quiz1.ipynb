# %%
import numpy as np
import matplotlib.pyplot as plt

from trusslib_v1_1 import *
from cross_truss import *

# %%
truss3 = setup_truss('cross_truss_3.txt')
truss3.draw()
truss3.solve()
truss3.plot(magnification=10, structure=False)
truss3.print_displacements()
ratio19 = truss3.stresses(1)/truss3.stresses(9)
print(ratio19)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 truss3 = setup_truss('cross_truss_3.txt')
#       2 truss3.draw()
#       3 truss3.solve()
#
# NameError: name 'setup_truss' is not defined
